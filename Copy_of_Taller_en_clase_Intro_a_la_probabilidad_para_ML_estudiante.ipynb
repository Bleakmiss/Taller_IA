# %% [markdown]
# <a href="https://colab.research.google.com/github/Bleakmiss/Taller_IA/blob/main/Copy_of_Taller_en_clase_Intro_a_la_probabilidad_para_ML_estudiante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller en clase #1
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=100000
m=3000
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750560000003

# %% [markdown]
# ## Primer punto binomial

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n,p = 300, 0.5

# %%
from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n,p, moments='mvsk')
r = binom.rvs(n,p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomialmente con p="+str(p)+ " y n="+str(n))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomialmente ordenados con p="+str(p)+" y n="+str(n))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p)+" y n="+str(n))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para el binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para el binomial con p=",p,"y n=",n,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para el binomial con p= 0.5 son u= 150.0 var= 75.0
# Los valores estimados en nuestro experimento de la media y varianza para el binomial con p= 0.5 y n= 300 son u_est= 149.868 var_est= 67.33657600000001

# %% [markdown]
# ##Segundo punto geometrico

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3

# %%
from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para el geometrico con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para el geometrico con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para el geometrico con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para el geometrico con p= 0.3 son u_est= 3.375 var_est= 7.590375

# %% [markdown]
# ## Tercer punto Poisson

# %%
# Poisson con cierto Lamnda L
L = 5

# %%
from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')
r = poisson.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente con L="+str(L))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con poisson ordenados con L="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos con poisson con L="+str(L))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para el poisson con L=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para el poisson con L=",L,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para el poisson con L= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para el poisson con L= 5 son u_est= 5.021 var_est= 4.578559

# %% [markdown]
# ##Cuarto punto Binomial negativo

# %%
#Binomial negativa con parametro p después de r fallos
rnbim,p = 5,0.5

# %%
from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(rnbim,p, moments='mvsk')
r = poisson.rvs(rnbim,p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial negativo con rnbim="+str(rnbim)+" y p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con binomial negativo ordenados con rnbim="+str(rnbim)+" y p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos con binomial negativo con rnbim="+str(rnbim)+" y p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para el binomial negativo con rnbim=",str(rnbim)," y p=",str(p),"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para el binomial negativo con rnbim=",str(rnbim)," y p=",str(p),"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para el binomial negativo con rnbim= 5  y p= 0.5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para el binomial negativo con rnbim= 5  y p= 0.5 son u_est= 5.061 var_est= 5.007279

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=10000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.971391002002103 var_est= 0.2653971302092896

# %% [markdown]
# ##Primer punto Uniforme

# %%
# Uniforme entre 0 y 255

# %%
from scipy.stats import uniform

mean, var, skew, kurt = uniform.stats(moments='mvsk',loc=0,scale=255)
r = uniform.rvs (loc=0,scale=255, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniformemente entre 0 y 255")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniforme ordenados entre 0 y 255")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos uniforme entre 0 y 255")
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la uniforme son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la uniforme son u= 127.5 var= 5418.75
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 127.62970721983449 var_est= 5428.719786246292

# %% [markdown]
# ##Segundo punto Exponencial

# %%
# Exponencial con Lamnda L
L=0.3

# %%
from scipy.stats import expon

mean, var, skew, kurt = expon.stats(moments='mvsk')
r = expon.rvs (L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencialmente con L= "+str(L))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencialmente ordenados con L= "+str(L))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencialmente con L= "+str(L))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la exponencial son u= 1.0 var= 1.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.292688835066806 var_est= 0.9818657579864576

# %% [markdown]
# ##Tercer punto Chi cuadrada

# %%
#Chi cuadrada con K grados de libertad
K=3.0

# %%
from scipy.stats import chi2

mean, var, skew, kurt = chi2.stats(df=K,moments='mvsk')
r = chi2.rvs (df=K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con chi cuadrado con K= "+str(K))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos chi cuadrado ordenados con K= "+str(K))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos chi cuadradado con K= "+str(K))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para chi cuadrado son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para chi cuadrado son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 3.0004993347409297 var_est= 5.979824284593806

# %% [markdown]
# ##Cuatro punto Gamma

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43

# %%
from scipy.stats import gamma

mean, var, skew, kurt = gamma.stats(a=k,scale=t,moments='mvsk')
r = gamma.rvs(a=k,scale=t, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con gamma con k= "+str(K)+" y t= "+ str(t))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos gamma ordenados con k= "+str(K)+" y t= "+ str(t))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos gamma con k= "+str(K)+" y t= "+ str(t))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para gamma son u= 1.0922 var= 0.469646
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.089961383465545 var_est= 0.4668271640583429
